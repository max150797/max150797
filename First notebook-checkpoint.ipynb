# %%
2+2
# Out:
# 4

# %%
5-98
# Out:
# -93

# %%
a = 'Hello world'
a
# Out:
# 'Hello world'

# %% [markdown]
# # Это заголовок первого уровня
# ## Это заголовок второго уровня
# Список:
# - Первый элемент **списка**
# - Второй элемент *списка*

# %%
x = (67+33)/25*(25-20)
x
# Out:
# 20.0

# %%
(4+5*60-17+65/4)**(0.5)
# Out:
# 17.414074767267998

# %%
6.996 + 45 * (13/2)**2 + 2 * 18**0.5
# Out:
# 1916.7312813742387

# %%
(1267-20*(5**3/2)**2)/(8**5 * 36**0.5)
# Out:
# -0.3909200032552083

# %%
(((9**0.5)**3)**2)**2/(-2)**-3
# Out:
# -4251528.0

# %%
type(12.0)
# Out:
# float

# %%
'hey'+'!'
# Out:
# 'hey!'

# %%
type(2+3.4)
# Out:
# float

# %%
type(2+3)
# Out:
# int

# %%
type(4 ** (1/2))
# Out:
# float

# %%
user_name = input('Введите свое имя: \n')
# Out:
# Введите свое имя:
# Максим

# %%
name = input("Как вас зовут?: \n")
print('Сегодня Вас зовут', name)
# Out:
# Как вас зовут?:
# Максим
# Сегодня Вас зовут Максим

# %%
word = input()
print(len(word))
# Out:
# Hello!
# 6

# %%
a = int(input())
b = int(input())
print(a % b)
# Out:
# 7
# 2
# 1

# %%
a = float(input())
b = float(input())
c = float(input())
print((a*b*c)**(1/3))
# Out:
# 17.213006207263156

# %%
x = float(input())
print(6.996 + 45 * (x/2)**2 + 2 * x)
# Out:
# 100500
# 113628013506.996

# %%
weight = float(input())
height = float(input())
print(weight/height**2)
# Out:
# 80
# 1.8
# 24.691358024691358

# %%
a = float(input())
b = float(input())
print(((a+b)/2)**(1/3))
# Out:
# 270
# 12.8
# 5.209745039548078

# %%
a = int(input())
print("Вы ввели число, которое при умножении на 3 даёт", a*3)
# Out:
# 10
# Вы ввели число, которое при умножении на 3 дает 30

# %%
string_1 = input()
string_2 = input()
string_3 = input()
a = (int(len(string_1)) * int(len(string_2)) * int(len(string_3)))**(1/3)
print(a)
# Out:
# Hello, world
# Python <3
# qwerty
# 8.653497421844449

# %%
string = input()
power = int(input())
length = len(string)
print(string, length, int(length) ** power)
# Out:
# Привет
# 2
# Привет 6 36

# %%
a = int(input())
b = int(input())

if a == b:
    print('Введены одинаковые числа')
else:
    print('Введены разные числа')
# Out:
# 1
# 2
# Введены разные числа

# %%
word = input()
if len(word) > 7:
    print('Это слово длинное.')
else:
    print('Это слово короткое.')
# Out:
# ОченьДлинноеСлово
# Это слово длинное

# %%
word = input()
if 'ф' in str(word):
    print("Ого! Вы ввели редкое слово!")
else:
    print("Эх, это не очень редкое слово...")
# Out:
# привет
# Эх, это не очень редкое слово...

# %%
word = input()
letter = input()
if letter in word:
    print("Выбранная буква есть в введённом слове")
else:
    print("Выбранной буквы нет в введённом слове")
# Out:
# Привет
# а
# Выбранной буквы нет в введённом слове

# %%
number = int(input())
sqrt_number = number ** 0.5
if sqrt_number == int(sqrt_number):
    print(int(sqrt_number))
else:
    print("Квадратный корень из", number, "- не целое число")
# Out:
# 10
# Квадратный корень из 10 - не целое число

# %%
number = int(input())
if number == 1:
    print('понедельник')
elif number == 2:
    print('вторник')
elif number == 3:
    print('среда')
elif number == 4:
    print('четверг')
elif number == 5:
    print('пятница')
elif number == 6:
    print('суббота')
elif number == 7:
    print('воскресенье')
# Out:
# 2
# вторник

# %%
weight = int(input())
height = float(input())
IMT = weight/height**2
if IMT < 18.5:
    print('Недостаточная масса тела')
elif 18.5 < IMT < 24.99:
    print('Норма')
elif IMT > 24.99:
    print('Избыточная масса тела')
# Out:
# 50
# 2
# Недостаточная масса тела

# %%
mark = int(input())
if mark < 4:
    print('неудовлетворительно')
elif mark == 4 or mark == 5:
    print('удовлетворительно')
elif mark == 6 or mark == 7:
    print('хорошо')
elif mark > 8:
    print('отлично')

# %%
balance = float(input())
if balance > 5000:
    print('Сегодня твой выбор - ресторан!')
elif 2500 < balance < 5000:
    print('Эх, только фастфуд.')
else:
    print('Придётся потерпеть!')
# Out:
# 456.5
# Придётся потерпеть!

# %%
number = int(input())
if number % 2 == 0:
    print('Число делится на 2 без остатка.')
elif number % 3 == 0:
    print('Число делится на 3 без остатка.')
elif number % 5 == 0:
    print('Число делится на 5 без остатка.')
else:
    print('Число не делится ни на 2, ни на 3, ни на 5 без остатка!')
# Out:
# 1
# Число не делится ни на 2, ни на 3, ни на 5 без остатка!

# %%
color = input('Укажите цвет: ') /n
flower = input()
if flower == 'роза' and (color == 'белый' or color == 'синий'):
    print('Ане понравятся эти цветы')
else:
    print('Аня не любит такие цветы')
